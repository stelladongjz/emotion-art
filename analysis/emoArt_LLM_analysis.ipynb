# %% [markdown]
# ## LLM Emotion + Likeness Rating & Explanation for Paintings

# %% [markdown]
# ### Model information: Gemini 2.5 flash
# ### Two prompts are used, a simple prompt and an enhanced prompt with rating score anchoring + explicitly asking the model to pay attention to low level features
# ### output "emotion_output.csv" from simple prompt and "emotion_output_enhanced.csv" for enhanced prompt

# %%
#import libraries

from google import genai
from google.genai import types
from google.api_core import exceptions as google_exceptions


import os
import re
import time
import random
import logging, sys
from pathlib import Path
import mimetypes

import pandas as pd
from tqdm import tqdm
from PIL import Image
from functools import reduce


# %run "api_key.ipynb" #import API key


logging.basicConfig(
    stream=sys.stdout,             
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%H:%M:%S")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/magics/execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'api_key.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[38], line 22
#      18 from PIL import Image
#      19 from functools import reduce
# ---> 22 get_ipython().run_line_magic('run', '"api_key.ipynb" #import API key')
#      25 logging.basicConfig(
#      26     stream=sys.stdout,
#      27     format="%(asctime)s [%(levelname)s] %(message)s",
#      28     datefmt="%H:%M:%S")
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/magics/execution.py:727, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     725     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     726         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 727     raise Exception(msg) from e
#     728 except TypeError:
#     729     if fpath in sys.meta_path:
#
# Exception: File `'api_key.ipynb'` not found.

# %% [markdown]
# ### Testing with prompts (numerical evaluation + text response explanation) for 20 images with Gemini
# #### For each emotion, write one model to produce output. Plus one aesthetic rating model.

# %%
#Configuratoins
IMAGE_FOLDER = Path("/Users/Stella/Desktop/EmotionArt/emotion-art/data/40_test")
OUTPUT_CSV   = Path("emotion_model_output.csv")
MODEL_NAME   = "gemini-2.5-flash"  
MAX_RETRIES  = 6
BACKOFF_BASE = 5.0  # seconds
DELAY_BETWEEN_CALLS = 0.5  # throttle to avoid hitting rate limits
BATCH_SIZE = 10
MAX_OUTPUT = 2049

#manage situations where there is hidden files such as .DS_Store
IMAGE_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".gif", ".tiff"}

#init client 
client = genai.Client(api_key = api_key)


def is_image_file(path: Path):
    return path.is_file() and path.suffix.lower() in IMAGE_EXTS and not path.name.startswith(".")

# preload & filter image paths
all_images = sorted(p for p in IMAGE_FOLDER.iterdir() if is_image_file(p))

# %%
all_images
# Out:
# [PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/1 1.47.27 AM.jpg'),
#  PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/a-grey-day-carmel.jpg'),
#  PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/alya-1964 1.47.27 AM.jpg'),
#  PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/coloured-wall-2003 1.47.27 AM.jpg'),
#  PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/explosion-lyrique-no-c-1918.jpg'),
#  PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/man-s-head.jpg'),
#  PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/movement-in-white-umber-and-cobalt-green-1950.png'),
#  PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/thursday-jeudi.jpg'),
#  PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/transparent-in-perspective-grooved-1921(1).jpg'),
#  PosixPath('/Users/Stella/Desktop/EmotionArt/emotion-art/ImagesAttentionFrame/10_test/untitled-1885.jpg')]

# %%
#prompts
def build_emotion_prompt(emotion: str) -> str:
    return (
        f"You are an art expert describing your emotional response to a painting.\n"
        f"Evaluate **{emotion.lower()}** independently, without reference to any other feeling. "
        "Do not assume anything about other possible emotional reactions — focus only on this one emotion.\n\n"
        "Provide your response using the following structure:\n"
        "1. A **numeric score** between 0 and 100 (on a continuous scale — do not round to nearest 5 or 10 unless warranted)\n"
        "2. A **detailed explanation** supporting the reason behind the rating you provided. Please try to be as detailed as possible.\n\n"
        f"Use the format exactly:\n"
        f"{emotion}: [score]\n"
        "Explanation: ..."
    )

# Prompt dictionary for loop call models later on with all emotions and liking rating:
prompt_dict = {emotion: build_emotion_prompt(emotion) for emotion in ["Joy", "Sadness", "Fear", "Anger", "Disgust", "Surprise"]}
prompt_dict["Liking"] = (
    "You are an art expert evaluating how much you like a painting.\n"
    "Rate your **personal aesthetic preference** for the painting, based only on what is visually presented.\n"
    "Provide your response using the following structure:\n"
    "1. A **numeric score** between 0 and 100 (on a continuous scale — do not round unless appropriate)\n"
    "2. A **detailed explanation** supporting the reason behind the rating you provided. Please try to be as detailed as possible.\n\n"
    "Use the format exactly:\n"
    "Liking: [score]\n"
    "Explanation: ..."
)

# %%
# Enhanced prompt that defines a clear scale anchors (0, 50, 100)
def build_emotion_prompt_enhanced(emotion: str) -> str:
    return (
        "You are an expert art critic and psychologist, trained to assess a viewer's emotional response"
        f"to a painting. Focus **only** on **{emotion.lower()}**—do not blend in any other feeling.\n\n"
        "**Scale definition (0-100):**  \n"
        f"- **0** means “no sense of {emotion.lower()} at all.”  \n"
        "- **50** means “a moderate, everyday level—what most people might feel in a typical scene.”  \n"
        f"- **100** means “an overwhelming, emotionally extreme sense of {emotion.lower()}.”\n\n"
        "**Instructions:**  \n"
        "1. Look closely at composition, color palette, lighting, brushwork, subject matter, and style.  \n"
        "2. Compare what you see to the anchors above—if it's slightly more than “everyday,” pick something like 60-70; if it barely registers, choose 5-10.  \n"
        f"3. Avoid clustering at 50: if the painting truly feels neutral for “{emotion.lower()},” explain why and use exactly 50; otherwise pick a number that reflects the visual evidence.  \n"
        "4. If you choose above 85 or below 15, you must justify why it crosses into “extreme” territory.  \n"
        "5. **Write exactly five complete sentences** in your explanation—no more, no fewer.  \n\n"
        "Provide your response using the following structure:\n"
        "1. A **numeric score** between 0 and 100 (on a continuous scale — do not round unless appropriate)\n"
        "2. A **detailed explanation** A detdescription of the visual elements (e.g., “the high-contrast reds and jagged lines give a surge of …”) that led you to that score. \n\n"
        "**Output format (exactly):**  \n"
        f"{emotion}: [score]\n"
        "Explanation: ..."
    )

prompt_dict_enhanced = {
    emotion: build_emotion_prompt_enhanced(emotion)
    for emotion in ["Joy", "Sadness", "Fear", "Anger", "Disgust", "Surprise"]
}

prompt_dict_enhanced["Liking"] = (
    "You are an expert art critic rating your own **aesthetic preference** for a painting on a 0-100 scale.\n\n"
    "**Scale definition (0-100):**  \n"
    "- **0** means “I wouldn't want this in my home or collection.”  \n"
    "- **50** means “it's average—interesting but not memorable.”  \n"
    "- **100** means “I find it utterly compelling and would absolutely display it.”\n\n"
    "**Instructions:**  \n"
    "1. Consider composition, color harmony, technique, originality, and emotional impact on *you*.  \n"
    "2. Anchor your number to the scale above—if your preference is tepid, choose 30-40; if you love it, choose 80-95.  \n"
    "3. Avoid mid-range clustering—only use 50 if it truly feels neutral.  \n"
    "4. If you go above 90 or below 10, explain why it's so extremely likable or unlikable.  \n"
    "5. **Write exactly five complete sentences** in your explanation—no more, no fewer.  \n\n"
    "Provide your response using the following structure:\n"
    "1. A **numeric score** between 0 and 100 (on a continuous scale — do not round unless appropriate)\n"
    "2. A **detailed explanation** supporting the reason behind the rating you provided. Please try to be as detailed as possible.\n\n"
    f"**Output format (exactly):**  \n"
    "Liking: [score]\n"
    "Explanation: ..."
)

# %%
# Regex to pull out the score and explanation
_SCORE_RE = re.compile(r"^[A-Za-z]+:\s*([\d.]+)", re.MULTILINE)
_EXPL_RE  = re.compile(r"Explanation:\s*(.*)", re.DOTALL)

def parse_response(raw: str) -> tuple[float|None, str]:
    # 1) Coerce into a str
    if raw is None:
        text = ""
    elif isinstance(raw, bytes):
        text = raw.decode("utf-8", errors="ignore")
    else:
        text = str(raw)

    # 2) Extract score and explanation
    m_score = _SCORE_RE.search(text)
    m_expl  = _EXPL_RE.search(text)
    if not (m_score and m_expl):
        # fallback: return entire text as explanation
        return None, text.strip()

    score       = float(m_score.group(1))
    explanation = m_expl.group(1).strip()
    return score, explanation

# %%
# Identify mime types of each image to be processed in the model

def get_mime_type(image_path: str) -> str:
    # Guess type, default to 'application/octet-stream' but we want image types
    mime_type, _ = mimetypes.guess_type(image_path)
    # Fallback for common cases:
    if mime_type is None:
        ext = os.path.splitext(image_path)[1].lower()
        if ext in ['.jpg', '.jpeg']:
            mime_type = 'image/jpeg'
        elif ext == '.png':
            mime_type = 'image/png'
        else:
            mime_type = 'application/octet-stream'
    return mime_type

# %%
# Wrapped call with retry/backoff
def emotion_model(image_path: str, prompt_text: str, emotion_label: str) -> dict:

    with open(image_path,"rb") as img_file:
        image_bytes = img_file.read()
        
    mime_type = get_mime_type(image_path)


    last_exc = None
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            resp = client.models.generate_content(
                model=MODEL_NAME,
                contents=[types.Part.from_bytes(data=image_bytes, mime_type=mime_type),
                          prompt_text],
                config = types.GenerateContentConfig(
                    max_output_tokens= MAX_OUTPUT
                )
            )

            if resp.candidates:
                raw = resp.candidates[0].content.parts[0].text
            else:
                raw = ""

            score, explanation = parse_response(raw)

            return {
                "image": Path(image_path).name,
                f"{emotion_label.lower()}_rating":      score,
                f"{emotion_label.lower()}_explanation": explanation
            }
        
        except google_exceptions.ServiceUnavailable as e:
            backoff = min(BACKOFF_BASE*2**(attempt-1), 30) + random.random()
            logging.warning(f"503 overload (try {attempt}), sleeping {backoff:.1f}s")
            time.sleep(backoff)

        except Exception as e:
            logging.warning(f"Error on try {attempt}: {e}")
            time.sleep(min(BACKOFF_BASE*2**(attempt-1), 30) + random.random())

    # if we get here, all retries were 503s or other failures—
    # return an “error” record rather than raising
    return {
        "image": Path(image_path).name,
        f"{emotion_label.lower()}_rating":      "",
        f"{emotion_label.lower()}_explanation": f"ERROR: model overloaded after {MAX_RETRIES} tries"
    }

# %%
#helper function to split a list into batches 
def chunker(seq, size):
    for i in range(0, len(seq), size):
        yield seq[i:i+size]

# %%
def get_response_by_emotion(
    emotion_label: str,
    prompt_dict,
    batch_size: int = BATCH_SIZE
):
    """
    Runs emotion_model on all_images in batches for the given emotion,
    logs progress, and saves output as a dataframe to be merged later.
    """
    records = []
    total = len(all_images)
    total_batches = (total + batch_size - 1) // batch_size

    for b_idx, batch in enumerate(chunker(all_images, batch_size), start=1):
        logging.info(f"Starting {emotion_label} batch {b_idx}/{total_batches} (size={len(batch)})")

        for i, img_path in enumerate(batch, start=1):
            idx = (b_idx - 1) * batch_size + i
            name = img_path.name
            logging.info(f"[{idx}/{total}] {emotion_label}: Processing {name}")

            try:
                rec = emotion_model(str(img_path), prompt_dict[emotion_label], emotion_label)
                logging.info(f"→ {emotion_label} Success: {name} → rating={rec[f'{emotion_label.lower()}_rating']}")
            except Exception as e:
                logging.error(f"❌ {emotion_label} error on {name}: {e}", exc_info=True)
                rec = {
                    "image":               name,
                    f"{emotion_label.lower()}_rating":      "",
                    f"{emotion_label.lower()}_explanation": f"ERROR: {e}"
                }

            records.append(rec)

    # Save to CSV
    output = pd.DataFrame(records)
    #out_path = output_dir / f"{emotion_label.lower()}_ratings.csv"
    #df.to_csv(out_path, index=False)
    #logging.info(f"✅ Saved {emotion_label} results to {out_path}")
    print(f"✅ {emotion_label} results successfully produced")
    return output

# %%
joy_output = get_response_by_emotion('Joy',  prompt_dict = prompt_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 joy_output = get_response_by_emotion('Joy', prompt_dict)
#
# Cell In[10], line 23, in get_response_by_emotion(emotion_label, prompt_dict, batch_size)
#      20 logging.info(f"[{idx}/{total}] {emotion_label}: Processing {name}")
#      22 try:
# ---> 23     rec = emotion_model(str(img_path), prompt_dict[emotion_label], emotion_label)
#      24     logging.info(f"→ {emotion_label} Success: {name} → rating={rec[f'{emotion_label.lower()}_rating']}")
#      25 except Exception as e:
#
# Cell In[8], line 12, in emotion_model(image_path, prompt_text, emotion_label)
#      10 for attempt in range(1, MAX_RETRIES + 1):
#      11     try:
# ---> 12         resp = client.models.generate_content(
#      13             model=MODEL_NAME,
#      14             contents=[types.Part.from_bytes(data=image_bytes, mime_type=mime_type),
#      15                       prompt_text],
#      16             config = types.GenerateContentConfig(
#      17                 max_output_tokens= MAX_OUTPUT
#      18             )
#      19         )
#      20         print(resp)
#      22         if resp.candidates:
#
# File /opt/anaconda3/lib/python3.12/site-packages/google/genai/models.py:5821, in Models.generate_content(self, model, contents, config)
#    5819 while remaining_remote_calls_afc > 0:
#    5820   i += 1
# -> 5821   response = self._generate_content(
#    5822       model=model, contents=contents, config=parsed_config
#    5823   )
#    5824   logger.info(f'AFC remote call {i} is done.')
#    5825   remaining_remote_calls_afc -= 1
#
# File /opt/anaconda3/lib/python3.12/site-packages/google/genai/models.py:4780, in Models._generate_content(self, model, contents, config)
#    4777 request_dict = _common.convert_to_dict(request_dict)
#    4778 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4780 response = self._api_client.request(
#    4781     'post', path, request_dict, http_options
#    4782 )
#    4784 response_dict = '' if not response.body else json.loads(response.body)
#    4786 if self._api_client.vertexai:
#
# File /opt/anaconda3/lib/python3.12/site-packages/google/genai/_api_client.py:986, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#     976 def request(
#     977     self,
#     978     http_method: str,
#    (...)
#     981     http_options: Optional[HttpOptionsOrDict] = None,
#     982 ) -> SdkHttpResponse:
#     983   http_request = self._build_request(
#     984       http_method, path, request_dict, http_options
#     985   )
# --> 986   response = self._request(http_request, stream=False)
#     987   response_body = response.response_stream[0] if response.response_stream else ''
#     988   return SdkHttpResponse(
#     989       headers=response.headers, body=response_body
#     990   )
#
# File /opt/anaconda3/lib/python3.12/site-packages/google/genai/_api_client.py:879, in BaseApiClient._request(self, http_request, stream)
#     874 def _request(
#     875     self,
#     876     http_request: HttpRequest,
#     877     stream: bool = False,
#     878 ) -> HttpResponse:
# --> 879   return self._retry(self._request_once, http_request, stream)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File /opt/anaconda3/lib/python3.12/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/tenacity/__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File /opt/anaconda3/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/anaconda3/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/anaconda3/lib/python3.12/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/anaconda3/lib/python3.12/site-packages/google/genai/_api_client.py:862, in BaseApiClient._request_once(self, http_request, stream)
#     858   return HttpResponse(
#     859       response.headers, response if stream else [response.text]
#     860   )
#     861 else:
# --> 862   response = self._httpx_client.request(
#     863       method=http_request.method,
#     864       url=http_request.url,
#     865       headers=http_request.headers,
#     866       content=data,
#     867       timeout=http_request.timeout,
#     868   )
#     869   errors.APIError.raise_for_response(response)
#     870   return HttpResponse(
#     871       response.headers, response if stream else [response.text]
#     872   )
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1233, in SSLSocket.recv(self, buflen, flags)
#    1229     if flags != 0:
#    1230         raise ValueError(
#    1231             "non-zero flags not allowed in calls to recv() on %s" %
#    1232             self.__class__)
# -> 1233     return self.read(buflen)
#    1234 else:
#    1235     return super().recv(buflen, flags)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1106, in SSLSocket.read(self, len, buffer)
#    1104         return self._sslobj.read(len, buffer)
#    1105     else:
# -> 1106         return self._sslobj.read(len)
#    1107 except SSLError as x:
#    1108     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
sadness_output = get_response_by_emotion('Sadness', prompt_dict = prompt_dict)
# Out:
# 14:42:06 [INFO] Starting Sadness batch 1/1 (size=10)
# 14:42:06 [INFO] [1/10] Sadness: Processing 1 1.47.27 AM.jpg
# 14:42:06 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:10 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:10 [INFO] AFC remote call 1 is done.
# Sadness: 78
# Explanation: The painting's somber color palette, dominated by deep reds, blues, and blacks, evokes a strong sense of sadness. The lack of clear definition or discernible imagery further contributes to this feeling, creating a sense of ambiguity and unease. The way the colors bleed into one another suggests a blurring of emotions, possibly representing grief or sorrow. The overall composition appears heavy and weighted down, adding to the overall melancholic tone.
# 14:42:10 [INFO] → Sadness Success: 1 1.47.27 AM.jpg → rating=78.0
# 14:42:10 [INFO] [2/10] Sadness: Processing a-grey-day-carmel.jpg
# 14:42:10 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:13 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:13 [INFO] AFC remote call 1 is done.
# Sadness: 32
# Explanation: The painting evokes a sense of melancholy sadness, primarily stemming from the muted color palette dominated by blues, grays, and subdued greens. The overcast sky and choppy water contribute to a feeling of somberness and the absence of vibrant colors or lively activity suggests a subdued emotional tone. While not overtly depressing, the painting lacks warmth and light, which generates a subtle sense of sorrow. The composition, with its vast sky and distant horizon, could also be interpreted as highlighting isolation or loneliness.
# 14:42:13 [INFO] → Sadness Success: a-grey-day-carmel.jpg → rating=32.0
# 14:42:13 [INFO] [3/10] Sadness: Processing alya-1964 1.47.27 AM.jpg
# 14:42:13 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:14 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:14 [INFO] AFC remote call 1 is done.
# Sadness: 15
# Explanation: The image contains bright, contrasting colors (green, red, and white) arranged in a symmetrical and somewhat playful pattern. There is nothing inherently sad about the image. The repetition and symmetrical nature is more visually stimulating than evoking a feeling of sadness. The rounded shapes suggest a soft, playful quality rather than anything mournful. It is difficult to associate sadness with this image beyond a very minimal level.
# 14:42:14 [INFO] → Sadness Success: alya-1964 1.47.27 AM.jpg → rating=15.0
# 14:42:14 [INFO] [4/10] Sadness: Processing coloured-wall-2003 1.47.27 AM.jpg
# 14:42:14 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:16 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:16 [INFO] AFC remote call 1 is done.
# Sadness: 35
# Explanation: The painting evokes a sense of quiet contemplation and perhaps a touch of melancholy, but not overwhelming sadness. The muted, earthy tones and the slightly faded quality of the watercolor technique contribute to this feeling. The arrangement of blocks, although structured, lacks a sense of joy or vibrant energy, which could add to the somber mood. However, the use of contrasting colors like orange and teal amidst the browns and yellows prevents the image from becoming overly depressing, keeping the sadness at a moderate level. The simple, almost childlike quality of the shapes might even suggest a naive acceptance of the world's imperfections, tempering any deep sorrow.
# 14:42:16 [INFO] → Sadness Success: coloured-wall-2003 1.47.27 AM.jpg → rating=35.0
# 14:42:16 [INFO] [5/10] Sadness: Processing explosion-lyrique-no-c-1918.jpg
# 14:42:16 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:18 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:18 [INFO] AFC remote call 1 is done.
# Sadness: 35
# Explanation: The painting evokes a moderate sense of sadness due to the somewhat somber color palette, particularly the use of blacks and blues in the lower portion of the figure's clothing. The abstracted and distorted forms may also contribute a feeling of unease or incompleteness, which, while not directly sad, lends itself to a melancholy feel. The woman's implied gesture could be interpreted as burdened or weary, furthering this sensation. However, the presence of brighter, warmer colors in the background and the implied motion prevent it from being deeply sorrowful.
# 14:42:18 [INFO] → Sadness Success: explosion-lyrique-no-c-1918.jpg → rating=35.0
# 14:42:18 [INFO] [6/10] Sadness: Processing man-s-head.jpg
# 14:42:18 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:18 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 503 Service Unavailable"
# 14:42:18 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 14:42:24 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:26 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:26 [INFO] AFC remote call 1 is done.
# Sadness: 65
# Explanation: The painting evokes a sense of sadness through several elements. The somber color palette, dominated by grays, purples, and muted yellows, creates a melancholic atmosphere. The subject's eyes, with their large, dark pupils and surrounding shadows, seem to convey a deep sense of sorrow or weariness. The fragmented and somewhat distorted features suggest a sense of inner turmoil or emotional fragmentation, further contributing to the overall feeling of sadness. Additionally, the textured brushstrokes and somewhat rough application of paint enhance the raw and vulnerable quality of the portrait, making it more emotionally resonant and sadness-inducing.
# 14:42:26 [INFO] → Sadness Success: man-s-head.jpg → rating=65.0
# 14:42:26 [INFO] [7/10] Sadness: Processing movement-in-white-umber-and-cobalt-green-1950.png
# 14:42:26 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:29 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:29 [INFO] AFC remote call 1 is done.
# Sadness: 45
# Explanation: The painting evokes a sense of sadness primarily through its muted color palette. The prevalence of browns, grays, and muted purples gives the artwork a somber and subdued atmosphere. The fragmented and chaotic composition contributes to the feeling of unease and disarray, which can trigger a sense of sadness. The visible brushstrokes and unfinished quality of the artwork also lend to a feeling of melancholy, as if the artist was struggling to capture a certain emotion or experience. While there is no immediately obvious source of sadness (e.g., a weeping figure), the overall mood and composition create a feeling of subdued sorrow. The angular lines and fragmented shapes suggest a sense of brokenness, which can evoke a feeling of sadness.
# 14:42:29 [INFO] → Sadness Success: movement-in-white-umber-and-cobalt-green-1950.png → rating=45.0
# 14:42:29 [INFO] [8/10] Sadness: Processing thursday-jeudi.jpg
# 14:42:29 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:29 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 503 Service Unavailable"
# 14:42:29 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 14:42:35 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:37 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:37 [INFO] AFC remote call 1 is done.
# Sadness: 55
# Explanation: The painting evokes a moderate sense of sadness through its muted color palette dominated by blues and purples, which are often associated with melancholy. The abstract, almost distorted figures, particularly the yellow face with minimal features, suggest a sense of isolation and dehumanization. The lack of clear narrative or expression on the face of the central figure contributes to a feeling of emotional distance and potential sorrow. While not overwhelmingly depressing, there's a pervasive sense of somber reflection present.
#
# 14:42:37 [INFO] → Sadness Success: thursday-jeudi.jpg → rating=55.0
# 14:42:37 [INFO] [9/10] Sadness: Processing transparent-in-perspective-grooved-1921(1).jpg
# 14:42:37 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:40 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:40 [INFO] AFC remote call 1 is done.
# Sadness: 30
# Explanation: The painting evokes a subdued sense of sadness. The use of muted colors such as browns and grays, combined with the fragmented and chaotic arrangement of shapes, creates a feeling of unease and instability. There's no single focal point, which might contribute to a feeling of disorientation and perhaps a sense of loss. The "transparent" or "perspective-laden" style in the title suggests a fleeting or incomplete view, which adds to a feeling of something missing or unobtainable. However, the splashes of red and yellow hint at some brightness, and the geometric structure provides a degree of order that prevents a truly overwhelming feeling of sadness. Therefore, it's a moderate, not an intense, sadness.
# 14:42:40 [INFO] → Sadness Success: transparent-in-perspective-grooved-1921(1).jpg → rating=30.0
# 14:42:40 [INFO] [10/10] Sadness: Processing untitled-1885.jpg
# 14:42:40 [INFO] AFC is enabled with max remote calls: 10.
# 14:42:42 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:42:42 [INFO] AFC remote call 1 is done.
# Sadness: 45
# Explanation: The painting evokes a sense of subdued sadness due to its muted color palette and the depiction of ships at rest in the harbor. The grey, overcast sky and the lack of vibrant colors contribute to a melancholic atmosphere. The detailed rendering of the ships, especially their bare masts and rigging, suggests a quiet stillness, perhaps reflecting the end of a journey or a period of inactivity. This sense of stillness, while visually appealing, also contributes to a feeling of loneliness and a subtle sense of sadness. The lack of visible human activity further amplifies this feeling.
# 14:42:42 [INFO] → Sadness Success: untitled-1885.jpg → rating=45.0
# 14:42:42 [INFO] ✅ Sadness results successfully produced

# %%
fear_output = get_response_by_emotion('Fear', prompt_dict = prompt_dict)
# Out:
# 14:33:24 [INFO] Starting Fear batch 1/1 (size=10)
# 14:33:24 [INFO] [1/10] Fear: Processing 1 1.47.27 AM.jpg
# 14:33:24 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:28 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:28 [INFO] AFC remote call 1 is done.
# Fear: 10
# Explanation: While the painting is somber and uses dark colors, which can sometimes evoke a sense of unease, it doesn't strongly trigger fear. The color blocks are static and lack sharp edges or dynamic elements that are more typically associated with fear-inducing imagery. The colors are not particularly threatening.
#
# 14:33:28 [INFO] → Fear Success: 1 1.47.27 AM.jpg → rating=10.0
# 14:33:28 [INFO] [2/10] Fear: Processing a-grey-day-carmel.jpg
# 14:33:28 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:30 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:30 [INFO] AFC remote call 1 is done.
# Fear: 12
# Explanation: The landscape depicted in the painting, with its rocky coastline and distant landmass, does not inherently evoke a strong sense of fear. The overall tone is calm and serene, with soft colors and brushstrokes. While the vastness of the sea might sometimes suggest a sense of vulnerability, there are no immediate threats or dangers visible in the artwork that would trigger a strong fear response. The presence of vegetation and a clear path suggest accessibility and exploration rather than isolation or dread. The somewhat subdued color palette mutes any potential intensity. The scene, though potentially isolating, does not depict any explicit dangers or threats, and is, in fact, quite placid.
# 14:33:30 [INFO] → Fear Success: a-grey-day-carmel.jpg → rating=12.0
# 14:33:30 [INFO] [3/10] Fear: Processing alya-1964 1.47.27 AM.jpg
# 14:33:30 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:32 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:32 [INFO] AFC remote call 1 is done.
# Fear: 1.5
# Explanation: The image consists of four green shapes, each containing a red square with a white border. The shapes are symmetrical and have rounded edges, giving them a friendly appearance. The colors are basic and non-threatening. The overall composition and arrangement lack any element that would typically evoke fear. There are no elements of horror, violence, uncertainty, or darkness. Thus, the level of fear is minimal to non-existent.
#
# 14:33:32 [INFO] → Fear Success: alya-1964 1.47.27 AM.jpg → rating=1.5
# 14:33:32 [INFO] [4/10] Fear: Processing coloured-wall-2003 1.47.27 AM.jpg
# 14:33:32 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:34 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:34 [INFO] AFC remote call 1 is done.
# Fear: 1.5
# Explanation: There is very little about this image that evokes fear. The colors are relatively muted and warm, and the composition of blocks is simple and calming. The watercolor effect gives it a soft, gentle feel. The overall effect is more of a tranquil or harmonious feeling than something that inspires fear. The slightly uneven edges of the color blocks do not convey any sense of threat or danger.
# 14:33:34 [INFO] → Fear Success: coloured-wall-2003 1.47.27 AM.jpg → rating=1.5
# 14:33:34 [INFO] [5/10] Fear: Processing explosion-lyrique-no-c-1918.jpg
# 14:33:34 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:35 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:35 [INFO] AFC remote call 1 is done.
# Fear: 15
# Explanation: The painting does not strongly evoke fear. While the abstract style could be unsettling to some, the bright colors and somewhat human figure depicted are not inherently frightening. The lack of sharp lines, threatening imagery, or chaotic composition further reduces any potential feeling of fear. The figure appears to be moving or dancing, and this motion is not suggestive of danger or threat. Therefore, any fear evoked by this painting is minimal.
# 14:33:35 [INFO] → Fear Success: explosion-lyrique-no-c-1918.jpg → rating=15.0
# 14:33:35 [INFO] [6/10] Fear: Processing man-s-head.jpg
# 14:33:35 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:37 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:37 [INFO] AFC remote call 1 is done.
# Fear: 45
# Explanation: The distorted and somewhat aggressive portrayal of the face contributes to a sense of unease and potential fear. The dark, staring eyes, coupled with the sharp, angular lines that define the face, create an unsettling effect. However, the abstract nature of the work and the use of colors that aren't entirely ominous mitigate the overall fear response. The lack of any clear threat or narrative context also prevents the image from being deeply frightening. The fear primarily arises from the unfamiliar and somewhat jarring presentation, rather than from explicit signs of danger.
#
# 14:33:37 [INFO] → Fear Success: man-s-head.jpg → rating=45.0
# 14:33:37 [INFO] [7/10] Fear: Processing movement-in-white-umber-and-cobalt-green-1950.png
# 14:33:37 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:40 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:40 [INFO] AFC remote call 1 is done.
# Fear: 22
# Explanation: The image evokes a sense of mild unease due to its fragmented, chaotic composition. The lack of clear forms and the disorienting angles create a feeling of instability, which is a characteristic of fear. However, the muted color palette, devoid of strong, contrasting hues, and the overall abstract nature of the painting mitigate any strong sense of alarm. The absence of recognizable threatening imagery, such as depictions of violence, aggression, or danger, also prevents a higher fear score. The painting feels unsettling but not overtly frightening.
#
# 14:33:40 [INFO] → Fear Success: movement-in-white-umber-and-cobalt-green-1950.png → rating=22.0
# 14:33:40 [INFO] [8/10] Fear: Processing thursday-jeudi.jpg
# 14:33:40 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:42 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:42 [INFO] AFC remote call 1 is done.
# Fear: 40
# Explanation: The painting evokes a sense of unease through its unusual composition, abstract shapes, and the use of a limited, cool color palette, predominantly blues and blacks. The figure with a bright yellow face and dark outlines could be perceived as menacing or alien, potentially inducing a feeling of apprehension. The darkness and the unknown forms add to the unsettling atmosphere, suggesting hidden threats or unseen dangers. However, the abstract nature and lack of clear narrative elements prevent a stronger sense of fear. The artwork is more intriguing and disorienting than genuinely frightening. It is the potential for a narrative that induces this sense of unease.
# 14:33:42 [INFO] → Fear Success: thursday-jeudi.jpg → rating=40.0
# 14:33:42 [INFO] [9/10] Fear: Processing transparent-in-perspective-grooved-1921(1).jpg
# 14:33:42 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:44 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:44 [INFO] AFC remote call 1 is done.
# Fear: 12
# Explanation: The image, "Transparent-perspectivisch gefügt (I)," by Paul Klee, evokes a very minimal sense of fear. The geometric shapes and transparent layers create a sense of instability and potential chaos, but this is largely tempered by the bright colors and playful composition. The lack of clear narrative or threatening imagery greatly reduces any potential for fear. The overall impression is more of abstract complexity than anything truly unsettling or frightening.
#
# 14:33:44 [INFO] → Fear Success: transparent-in-perspective-grooved-1921(1).jpg → rating=12.0
# 14:33:44 [INFO] [10/10] Fear: Processing untitled-1885.jpg
# 14:33:44 [INFO] AFC is enabled with max remote calls: 10.
# 14:33:47 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:33:47 [INFO] AFC remote call 1 is done.
# Fear: 15
# Explanation: There is a lack of visual elements in this painting that evoke a sense of fear. The sky, although perhaps cloudy, isn't particularly threatening. The ships, while possibly imposing in real life, are depicted in a way that feels calm and static. The scene as a whole is somewhat muted and lacking any strong indication of danger or threat. Perhaps if the ships were being tossed around in a storm, or there was another source of darkness and danger, my perception would be different. However, the peaceful impression I am given here is quite the opposite of something scary or anxiety-inducing.
# 14:33:47 [INFO] → Fear Success: untitled-1885.jpg → rating=15.0
# 14:33:47 [INFO] ✅ Fear results successfully produced

# %%
anger_output = get_response_by_emotion('Anger', prompt_dict = prompt_dict)
# Out:
# 14:34:39 [INFO] Starting Anger batch 1/1 (size=10)
# 14:34:39 [INFO] [1/10] Anger: Processing 1 1.47.27 AM.jpg
# 14:34:39 [INFO] AFC is enabled with max remote calls: 10.
# 14:34:43 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:34:43 [INFO] AFC remote call 1 is done.
# Anger: 15
# Explanation: The painting evokes a sense of solemnity and contemplation, rather than direct agitation or frustration. The deep reds and blues can suggest a weighty or somber mood, but not necessarily an angry one. The lack of sharp lines or aggressive brushstrokes further diffuses any immediate sense of anger, contributing to a more subdued feeling overall. The colors themselves are not inherently angry colors, and the hazy, soft edges are not associated with strong emotions such as anger.
# 14:34:43 [INFO] → Anger Success: 1 1.47.27 AM.jpg → rating=15.0
# 14:34:43 [INFO] [2/10] Anger: Processing a-grey-day-carmel.jpg
# 14:34:43 [INFO] AFC is enabled with max remote calls: 10.
# 14:34:45 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:34:45 [INFO] AFC remote call 1 is done.
# Anger: 5
# Explanation: The painting is peaceful and serene. The cool colors, the gentle waves, and the soft brushstrokes do not evoke any sense of anger. The lack of harsh lines or conflict within the scene further diminishes any feeling of anger. The overall mood is calming and tranquil.
#
# 14:34:45 [INFO] → Anger Success: a-grey-day-carmel.jpg → rating=5.0
# 14:34:45 [INFO] [3/10] Anger: Processing alya-1964 1.47.27 AM.jpg
# 14:34:45 [INFO] AFC is enabled with max remote calls: 10.
# 14:34:46 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:34:46 [INFO] AFC remote call 1 is done.
# Anger: 5
# Explanation: The image doesn't evoke a sense of anger. The colors are somewhat muted and the shapes are simple. There is nothing aggressive, confrontational, or upsetting about the image that would trigger an angry response. It is quite a benign, visually simple design.
# 14:34:46 [INFO] → Anger Success: alya-1964 1.47.27 AM.jpg → rating=5.0
# 14:34:46 [INFO] [4/10] Anger: Processing coloured-wall-2003 1.47.27 AM.jpg
# 14:34:46 [INFO] AFC is enabled with max remote calls: 10.
# 14:34:48 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:34:48 [INFO] AFC remote call 1 is done.
# Anger: 15
# Explanation: The painting, with its gentle colors and simple geometric shapes, doesn't evoke strong negative emotions like anger. While the blocks might represent confinement or restriction to some extent, the overall effect is muted and calming, rather than aggressive or frustrating. The watercolor medium softens the edges and blends colors, further reducing the likelihood of generating anger. The lack of harsh lines or clashing colors works against this emotion. Overall, it seems a gentle piece, rather than something that would provoke any substantial anger.
# 14:34:48 [INFO] → Anger Success: coloured-wall-2003 1.47.27 AM.jpg → rating=15.0
# 14:34:48 [INFO] [5/10] Anger: Processing explosion-lyrique-no-c-1918.jpg
# 14:34:48 [INFO] AFC is enabled with max remote calls: 10.
# 14:34:50 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:34:50 [INFO] AFC remote call 1 is done.
# Anger: 3
# Explanation: The painting does not evoke a strong sense of anger. The bright, contrasting colors and abstract style, while potentially unsettling, don't directly translate to feelings of rage or frustration. There's no depiction of violence, conflict, or any of the typical visual cues associated with anger. The abstract nature of the subject matter also prevents any clear narrative that might elicit anger.
#
# 14:34:50 [INFO] → Anger Success: explosion-lyrique-no-c-1918.jpg → rating=3.0
# 14:34:50 [INFO] [6/10] Anger: Processing man-s-head.jpg
# 14:34:50 [INFO] AFC is enabled with max remote calls: 10.
# 14:34:53 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:34:53 [INFO] AFC remote call 1 is done.
# Anger: 35
# Explanation: The painting evokes a mild sense of unease and discomfort, which could be interpreted as a low level of anger. The harsh lines and somewhat distorted features, particularly around the eyes and mouth, might suggest a suppressed frustration or internal conflict, rather than outright rage. The color palette doesn't seem to contribute directly to anger, but the overall texture and composition hint at an underlying tension, contributing to the moderate score. It doesn't trigger any immediate strong emotional response, but rather a subtle sense of displeasure or repressed annoyance.
# 14:34:53 [INFO] → Anger Success: man-s-head.jpg → rating=35.0
# 14:34:53 [INFO] [7/10] Anger: Processing movement-in-white-umber-and-cobalt-green-1950.png
# 14:34:53 [INFO] AFC is enabled with max remote calls: 10.
# 14:34:55 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:34:55 [INFO] AFC remote call 1 is done.
# Anger: 15
# Explanation: The painting evokes a very mild sense of unease rather than outright anger. The fractured, chaotic composition, with its sharp lines and clashing planes, creates a slight tension that could be interpreted as a precursor to anger, but it's too muted to be a dominant emotion. The subdued color palette, dominated by browns, whites, and muted purples, further softens any potential for anger, making it more of a feeling of confusion or mild frustration than outright rage or indignation. The dynamic composition and scattered brushstrokes could perhaps be seen as reflecting a disturbed state, but there is no direct aggressive or violent element.
#
# 14:34:55 [INFO] → Anger Success: movement-in-white-umber-and-cobalt-green-1950.png → rating=15.0
# 14:34:55 [INFO] [8/10] Anger: Processing thursday-jeudi.jpg
# 14:34:55 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:01 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:01 [INFO] AFC remote call 1 is done.
# Anger: 28
# Explanation: The painting has a somewhat unsettling quality, but it doesn't evoke a strong feeling of anger. The use of dark blues could suggest a sense of unease or melancholy, which could be related to anger, but it's not directly suggestive of rage or frustration. The bright yellow figure seems out of place in the dark setting, which may convey a sense of awkwardness or confusion, but not necessarily anger. The overall composition feels more strange than aggressive.
# 14:35:01 [INFO] → Anger Success: thursday-jeudi.jpg → rating=28.0
# 14:35:01 [INFO] [9/10] Anger: Processing transparent-in-perspective-grooved-1921(1).jpg
# 14:35:01 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:06 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:06 [INFO] AFC remote call 1 is done.
# Anger: 15
# Explanation: The artwork's abstract nature, with its geometric shapes and muted color palette, does not evoke intense feelings of anger. There is some tension in the overlapping lines and fragmented composition, suggesting mild unease, but the colors are too desaturated and the forms too ambiguous to generate a strong feeling of anger. The overall impression is one of intellectual curiosity and restrained emotion rather than rage or fury.
# 14:35:06 [INFO] → Anger Success: transparent-in-perspective-grooved-1921(1).jpg → rating=15.0
# 14:35:06 [INFO] [10/10] Anger: Processing untitled-1885.jpg
# 14:35:06 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:07 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:07 [INFO] AFC remote call 1 is done.
# Anger: 12
# Explanation: The painting evokes a sense of tranquility and calmness with its soft colors and depiction of boats at rest. The brushstrokes are gentle, and the overall atmosphere is peaceful. There is no element within the artwork that would suggest any level of anger.
#
# 14:35:07 [INFO] → Anger Success: untitled-1885.jpg → rating=12.0
# 14:35:07 [INFO] ✅ Anger results successfully produced

# %%
disgust_output = get_response_by_emotion('Disgust', prompt_dict = prompt_dict)
# Out:
# 14:35:35 [INFO] Starting Disgust batch 1/1 (size=10)
# 14:35:35 [INFO] [1/10] Disgust: Processing 1 1.47.27 AM.jpg
# 14:35:35 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:39 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:39 [INFO] AFC remote call 1 is done.
# Disgust: 15
# Explanation: The painting's colors, a dark brown and blue, aren't colors that inherently evoke disgust. The composition is also quite simple. However, there is something about the murkiness and dullness that inspires slight unpleasantness. It's not overwhelming, but I'm not excited to look at it. This mild aversion translates into a low level of disgust. It lacks any sort of vibrancy that would make it interesting, and just feels like something I'd rather not stare at. The colors are also reminiscent of something rotting.
# 14:35:39 [INFO] → Disgust Success: 1 1.47.27 AM.jpg → rating=15.0
# 14:35:39 [INFO] [2/10] Disgust: Processing a-grey-day-carmel.jpg
# 14:35:39 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:41 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:41 [INFO] AFC remote call 1 is done.
# Disgust: 3
# Explanation: The painting evokes a very minimal sense of disgust. The landscape isn't particularly repulsive, and the colors and brushstrokes don't suggest anything inherently unclean or decayed. The scene is a natural landscape, showing a rocky coastline and sea, with no elements that strongly elicit repulsion. The overall impression is of a natural scene depicted in a somewhat coarse manner, but it does not contain elements likely to provoke disgust. It is possible that someone might feel a faint discomfort due to the potentially harsh environment, but it's not a prominent emotion prompted by the work.
# 14:35:41 [INFO] → Disgust Success: a-grey-day-carmel.jpg → rating=3.0
# 14:35:41 [INFO] [3/10] Disgust: Processing alya-1964 1.47.27 AM.jpg
# 14:35:41 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:43 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:43 [INFO] AFC remote call 1 is done.
# Disgust: 5
# Explanation: The image doesn't evoke a strong sense of disgust. While the color combination is a bit odd and the shapes are somewhat unnatural, they don't trigger any feelings of revulsion or aversion. It's mostly neutral. The high saturation is slightly unsettling, but not disgust-inducing.
#
# 14:35:43 [INFO] → Disgust Success: alya-1964 1.47.27 AM.jpg → rating=5.0
# 14:35:43 [INFO] [4/10] Disgust: Processing coloured-wall-2003 1.47.27 AM.jpg
# 14:35:43 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:44 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:44 [INFO] AFC remote call 1 is done.
# Disgust: 5
# Explanation: There is nothing inherently disgusting about the image. The colors are mostly muted and earthy, and the geometric forms are simple and organized. The slight imperfections in the watercolor style could be interpreted as mildly unpleasant by some, hence the low score.
#
# 14:35:44 [INFO] → Disgust Success: coloured-wall-2003 1.47.27 AM.jpg → rating=5.0
# 14:35:44 [INFO] [5/10] Disgust: Processing explosion-lyrique-no-c-1918.jpg
# 14:35:44 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:45 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:45 [INFO] AFC remote call 1 is done.
# Disgust: 15
# Explanation: The painting's abstract nature and vibrant colors prevent a strong feeling of disgust. While the figure's distorted features could potentially evoke a slight sense of unease, it's more aligned with unfamiliarity than outright revulsion. The color palette, though unusual, adds a visual appeal that offsets any potentially disgusting elements. The composition is too stylized and expressive to elicit significant disgust.
#
# 14:35:45 [INFO] → Disgust Success: explosion-lyrique-no-c-1918.jpg → rating=15.0
# 14:35:45 [INFO] [6/10] Disgust: Processing man-s-head.jpg
# 14:35:45 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:48 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:48 [INFO] AFC remote call 1 is done.
# Disgust: 25
# Explanation: The painting does not evoke intense disgust, but there are elements that contribute to a mild sense of it. The distortions of the face, particularly the somewhat grotesque shaping of the nose and mouth with the strange colors in the mouth area, and the starkness of the eyes, create a sense of unease. The texture of the paint, which appears thick and almost crude in its application, might also contribute to a feeling of slight aversion, though the impact on the overall visual appeal is minimal. It leans more towards disorientation and artistic expression than pure revulsion.
# 14:35:48 [INFO] → Disgust Success: man-s-head.jpg → rating=25.0
# 14:35:48 [INFO] [7/10] Disgust: Processing movement-in-white-umber-and-cobalt-green-1950.png
# 14:35:48 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:50 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:50 [INFO] AFC remote call 1 is done.
# Disgust: 2.5
# Explanation: The painting evokes a very mild feeling of disgust. This is primarily due to the chaotic and somewhat jarring composition. The indistinct forms and the muddy color palette also contribute, albeit weakly. However, the overall effect is more of disinterest than true disgust. The low score reflects the very weak presence of this emotion.
#
# 14:35:50 [INFO] → Disgust Success: movement-in-white-umber-and-cobalt-green-1950.png → rating=2.5
# 14:35:50 [INFO] [8/10] Disgust: Processing thursday-jeudi.jpg
# 14:35:50 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:51 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:51 [INFO] AFC remote call 1 is done.
# Disgust: 10
# Explanation: The painting doesn't evoke strong feelings of disgust. The abstract nature and use of vibrant colors prevent it from being repulsive. There is nothing inherently offensive or vile in the imagery, so the disgust score is low.
# 14:35:51 [INFO] → Disgust Success: thursday-jeudi.jpg → rating=10.0
# 14:35:51 [INFO] [9/10] Disgust: Processing transparent-in-perspective-grooved-1921(1).jpg
# 14:35:51 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:53 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:53 [INFO] AFC remote call 1 is done.
# Disgust: 2
# Explanation: The disjointedness and lack of clear representation don't evoke any strong revulsion. While the brown and red colours used could be seen as slightly unappetizing in certain contexts, the overall effect isn't unpleasant enough to trigger any significant sense of disgust. The abstract nature makes it difficult to associate with anything inherently disgusting.
#
# 14:35:53 [INFO] → Disgust Success: transparent-in-perspective-grooved-1921(1).jpg → rating=2.0
# 14:35:53 [INFO] [10/10] Disgust: Processing untitled-1885.jpg
# 14:35:53 [INFO] AFC is enabled with max remote calls: 10.
# 14:35:55 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:35:55 [INFO] AFC remote call 1 is done.
# Disgust: 5
# Explanation: The painting does not evoke any strong feelings of disgust. The harbor scene, even with its potential for pollution and decay, is presented in a way that is aesthetically pleasing and does not trigger revulsion. The muted color palette and the artistic style lend a sense of serenity rather than unease. There are no elements within the painting, such as rotting matter or overt displays of uncleanliness, that would lead to a feeling of disgust.
#
# 14:35:55 [INFO] → Disgust Success: untitled-1885.jpg → rating=5.0
# 14:35:55 [INFO] ✅ Disgust results successfully produced

# %%
surprise_output = get_response_by_emotion('Surprise', prompt_dict = prompt_dict)
# Out:
# 14:36:21 [INFO] Starting Surprise batch 1/1 (size=10)
# 14:36:21 [INFO] [1/10] Surprise: Processing 1 1.47.27 AM.jpg
# 14:36:21 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:25 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:25 [INFO] AFC remote call 1 is done.
# Surprise: 20
# Explanation: The painting has a very simple, minimalist composition consisting of three horizontal blocks of color, with a border of the same blue as the middle section encompassing the whole image. The colors are dark and somber with no unexpected or unusual elements. It is possible to feel surprise upon initial viewing because it is rather abstract, but after some contemplation, the painting doesn't provide anything particularly shocking or unusual, thereby reducing the degree of surprise it elicits.
# 14:36:25 [INFO] → Surprise Success: 1 1.47.27 AM.jpg → rating=20.0
# 14:36:25 [INFO] [2/10] Surprise: Processing a-grey-day-carmel.jpg
# 14:36:25 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:27 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:27 [INFO] AFC remote call 1 is done.
# Surprise: 23
# Explanation: The painting depicts a familiar scene of a coastline. The composition, with its clear layers of land, sea, and sky, is predictable. The muted color palette and loose brushstrokes, while aesthetically pleasing, don't introduce any elements that would cause surprise. The lack of any unexpected objects, unusual perspectives, or striking contrasts contributes to a low score for surprise. It's a pleasant, traditional landscape, but it doesn't challenge expectations.
# 14:36:27 [INFO] → Surprise Success: a-grey-day-carmel.jpg → rating=23.0
# 14:36:27 [INFO] [3/10] Surprise: Processing alya-1964 1.47.27 AM.jpg
# 14:36:27 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:29 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:29 [INFO] AFC remote call 1 is done.
# Surprise: 10
# Explanation: The image is quite straightforward. There is nothing unexpected or unusual about the composition, color palette, or subject matter to evoke surprise. It's a simple pattern repeated four times, easily understandable and predictable, which is why the surprise score is low.
# 14:36:29 [INFO] → Surprise Success: alya-1964 1.47.27 AM.jpg → rating=10.0
# 14:36:29 [INFO] [4/10] Surprise: Processing coloured-wall-2003 1.47.27 AM.jpg
# 14:36:29 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:31 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:31 [INFO] AFC remote call 1 is done.
# Surprise: 30
# Explanation: The painting, titled "Coloured Wall," features a grid-like arrangement of rectangular blocks in various muted earth tones and some brighter colors like yellow. The composition is relatively straightforward, and the colors, while pleasant, are not particularly shocking or unexpected. The style, which appears to be watercolor or a similar translucent medium, is also fairly conventional. The overall effect is harmonious but lacks any jarring or unusual elements that would evoke a strong sense of surprise. While the combination of colors is interesting, it doesn't present anything novel or unexpected enough to significantly raise the surprise factor. Therefore, the surprise rating is relatively low. The slight element of surprise comes from the non-exact nature of the rectangles and the overall watery effect.
# 14:36:31 [INFO] → Surprise Success: coloured-wall-2003 1.47.27 AM.jpg → rating=30.0
# 14:36:31 [INFO] [5/10] Surprise: Processing explosion-lyrique-no-c-1918.jpg
# 14:36:31 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:33 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:33 [INFO] AFC remote call 1 is done.
# Surprise: 30
# Explanation: The painting has an abstract style, with a figure surrounded by colorful, flowing lines. While the colors and brushstrokes are bold and eye-catching, they don't necessarily evoke a strong sense of surprise. There isn't an unexpected element, sudden change, or unusual combination that would elicit a jolt of surprise. The composition is somewhat chaotic, but it seems more expressive of a certain mood or feeling rather than a sudden unexpected event, so my surprise is low.
# 14:36:33 [INFO] → Surprise Success: explosion-lyrique-no-c-1918.jpg → rating=30.0
# 14:36:33 [INFO] [6/10] Surprise: Processing man-s-head.jpg
# 14:36:33 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:35 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:35 [INFO] AFC remote call 1 is done.
# Surprise: 65
# Explanation: The unexpected color palette, with its bold use of purple, yellow, and orange against the gray and brown, immediately catches the eye and feels surprising. The almost geometric deconstruction of the face, while rooted in cubism, is executed in a unique and slightly jarring manner. The grid-like texture overlaid on parts of the face also feels unusual and adds to the element of surprise. The large, dark eyes also contribute to this effect, drawing the viewer in with an almost confrontational stare. However, it's not a complete shock because the style is somewhat familiar. It's a pleasant surprise, a deviation from the norm that sparks interest without being totally bizarre.
# 14:36:35 [INFO] → Surprise Success: man-s-head.jpg → rating=65.0
# 14:36:35 [INFO] [7/10] Surprise: Processing movement-in-white-umber-and-cobalt-green-1950.png
# 14:36:35 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:38 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:38 [INFO] AFC remote call 1 is done.
# Surprise: 45
# Explanation: The abstract nature of the artwork, with its chaotic arrangement of shapes and colors, does elicit a moderate level of surprise. The lack of clear representation or recognizable subject matter forces the viewer to confront the unexpected and interpret the artist's intent. However, the limited color palette and generally subdued tone diminish the potential for a truly shocking or startling experience, thus a lower surprise rating. The presence of "Marin 50" in the corner suggests this is not random art, which mitigates against surprise too.
#
# 14:36:38 [INFO] → Surprise Success: movement-in-white-umber-and-cobalt-green-1950.png → rating=45.0
# 14:36:38 [INFO] [8/10] Surprise: Processing thursday-jeudi.jpg
# 14:36:38 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:40 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:40 [INFO] AFC remote call 1 is done.
# Surprise: 65
# Explanation: The painting is unusual and unexpected. The colors, the shapes, and the overall composition create a sense of novelty, which elicits a feeling of surprise. I am surprised by the starkness of the colors against the dark background, and the abstraction of the shapes also leads to a moderate sense of surprise. The painting is not overly realistic or conventional, so it generates a sense of novelty and wonder, which further increases the feeling of surprise.
# 14:36:40 [INFO] → Surprise Success: thursday-jeudi.jpg → rating=65.0
# 14:36:40 [INFO] [9/10] Surprise: Processing transparent-in-perspective-grooved-1921(1).jpg
# 14:36:40 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:42 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:42 [INFO] AFC remote call 1 is done.
# Surprise: 72
# Explanation: The painting evokes a moderate-to-high level of surprise due to its unconventional and somewhat chaotic arrangement of geometric forms. The transparency effects and overlapping lines create a sense of disorientation, challenging traditional spatial understanding. The combination of vibrant colors and abstract shapes further contributes to the unexpected visual experience. While there are familiar elements like building structures, the deconstructed and reassembled perspective creates a unique and somewhat jarring experience that sparks a genuine sense of surprise. It is not profoundly shocking, but certainly intriguing and unusual.
# 14:36:42 [INFO] → Surprise Success: transparent-in-perspective-grooved-1921(1).jpg → rating=72.0
# 14:36:42 [INFO] [10/10] Surprise: Processing untitled-1885.jpg
# 14:36:42 [INFO] AFC is enabled with max remote calls: 10.
# 14:36:44 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:36:44 [INFO] AFC remote call 1 is done.
# Surprise: 4.
# Explanation: This painting evokes very little surprise. The subject matter of a harbor scene with ships is quite conventional, and the impressionistic style, while beautiful, is not unexpected. The color palette and composition are harmonious and predictable, lending to a sense of calm familiarity rather than shock or unexpectedness. There are no unusual elements that might cause a viewer to feel taken aback or astonished. The painting possesses an aesthetic appeal but does not introduce any new perspectives or visual jolts that could generate surprise.
# 14:36:44 [INFO] → Surprise Success: untitled-1885.jpg → rating=4.0
# 14:36:44 [INFO] ✅ Surprise results successfully produced

# %%
liking_output = get_response_by_emotion('Liking', prompt_dict = prompt_dict)
# Out:
# 14:37:12 [INFO] Starting Liking batch 1/1 (size=10)
# 14:37:12 [INFO] [1/10] Liking: Processing 1 1.47.27 AM.jpg
# 14:37:12 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:15 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:15 [INFO] AFC remote call 1 is done.
# Liking: 75
# Explanation: The painting is a color field painting featuring three horizontal bands of color: a dark red-brown at the top, a medium blue in the middle, and a darker blue at the bottom. The painting has a slightly muted, somber feel. I find the color composition pleasing. The subtle variations in tone within each band add depth and visual interest. The overall effect is calming and contemplative, which I appreciate. I'm not giving it a higher score simply because while I think the painting works well, I wouldn't be excited to display it.
# 14:37:15 [INFO] → Liking Success: 1 1.47.27 AM.jpg → rating=75.0
# 14:37:15 [INFO] [2/10] Liking: Processing a-grey-day-carmel.jpg
# 14:37:15 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:17 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:17 [INFO] AFC remote call 1 is done.
# Liking: 88
# Explanation: This painting evokes a sense of peacefulness and tranquility. The brushstrokes are loose and impressionistic, creating a soft, dreamlike quality. The color palette is dominated by blues, greens, and whites, which contribute to the serene atmosphere. I appreciate the artist's ability to capture the subtle variations in light and shadow, giving the scene a sense of depth and realism. The composition is well-balanced, with the coastline, sea, and sky seamlessly blending together. Overall, the painting is visually appealing and aesthetically pleasing.
# The artist captured the mood of the coastal landscape perfectly, with a sense of calm and tranquility prevailing. It makes me wish I could be there, in that moment and place, taking in the fresh air and the sounds of the waves.
#
# 14:37:17 [INFO] → Liking Success: a-grey-day-carmel.jpg → rating=88.0
# 14:37:17 [INFO] [3/10] Liking: Processing alya-1964 1.47.27 AM.jpg
# 14:37:17 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:18 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 503 Service Unavailable"
# 14:37:18 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 14:37:23 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:26 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:26 [INFO] AFC remote call 1 is done.
# Liking: 55
# Explanation: The image features four identical objects arranged in a grid. Each object has a green, bone-like shape with a central red square surrounded by a white border. My rating reflects the following considerations:
#
# *   **Repetitive design:** The identical nature and grid-like arrangement contribute to a sense of order and predictability, which can be appealing but also lacks dynamism and surprise. This reduces my personal enjoyment.
#
# *   **Color palette:** The color combination of green, red, and white is somewhat pleasing but doesn't evoke a strong emotional response. The green might be seen as a calming background, with the red as a focal point, but the white border is a bit harsh.
#
# *   **Shape and form:** The bone-like shape of the outer green part is not especially compelling or visually interesting to me. The central square is simple and familiar, leading to a neutral or slightly negative preference.
#
# Overall, the image is fairly simple in design, lacking a strong aesthetic appeal.
# 14:37:26 [INFO] → Liking Success: alya-1964 1.47.27 AM.jpg → rating=55.0
# 14:37:26 [INFO] [4/10] Liking: Processing coloured-wall-2003 1.47.27 AM.jpg
# 14:37:26 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:28 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:28 [INFO] AFC remote call 1 is done.
# Liking: 75
# Explanation: I find the painting aesthetically pleasing, primarily because of its use of color and geometric forms. The arrangement of rectangular blocks in various warm and cool tones creates a visually engaging composition. The watercolor-like texture gives the piece a soft, almost ethereal quality, which I appreciate. The way the colors bleed into each other adds depth and interest. However, I feel it lacks a certain complexity or narrative that would elevate it further, thus stopping the rating from being higher.
# 14:37:28 [INFO] → Liking Success: coloured-wall-2003 1.47.27 AM.jpg → rating=75.0
# 14:37:28 [INFO] [5/10] Liking: Processing explosion-lyrique-no-c-1918.jpg
# 14:37:28 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:29 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:29 [INFO] AFC remote call 1 is done.
# Liking: 75
# Explanation: I find the painting visually appealing due to its vibrant and expressive use of color. The artist's bold brushstrokes and abstract representation of the figure create a sense of movement and energy. I appreciate the non-traditional color palette and how it contributes to the painting's overall dynamism. While the abstraction might not be everyone's preference, I find it engaging and thought-provoking.
#
# 14:37:29 [INFO] → Liking Success: explosion-lyrique-no-c-1918.jpg → rating=75.0
# 14:37:29 [INFO] [6/10] Liking: Processing man-s-head.jpg
# 14:37:29 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:31 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:31 [INFO] AFC remote call 1 is done.
# Liking: 75
# Explanation: I find the painting aesthetically intriguing. The cubist style and the abstract rendering of the face are captivating. The use of color, particularly the mix of grays, yellows, and purples, creates a visually stimulating contrast. The textured strokes and the grid-like patterns overlaid on the face add depth and complexity to the composition. While not conventionally beautiful, the painting holds my attention and evokes a sense of curiosity, thus my liking of 75.
# 14:37:31 [INFO] → Liking Success: man-s-head.jpg → rating=75.0
# 14:37:31 [INFO] [7/10] Liking: Processing movement-in-white-umber-and-cobalt-green-1950.png
# 14:37:31 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:34 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:34 [INFO] AFC remote call 1 is done.
# Liking: 75
# Explanation: This is a vibrant, semi-abstract watercolor painting. I appreciate its dynamic composition, employing a cubist-inspired fracturing of space and form. The limited palette of white, brown, and lilac-gray creates a cohesive and harmonious effect. The brushwork is loose and expressive, conveying a sense of spontaneity and energy. While the overall image is somewhat ambiguous, it evokes a sense of movement and urban landscape. I particularly enjoy the interplay of the sharp lines and geometric shapes against the softer washes of color. The overall effect is visually intriguing and aesthetically pleasing.
# 14:37:34 [INFO] → Liking Success: movement-in-white-umber-and-cobalt-green-1950.png → rating=75.0
# 14:37:34 [INFO] [8/10] Liking: Processing thursday-jeudi.jpg
# 14:37:34 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:36 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:36 [INFO] AFC remote call 1 is done.
# Liking: 75
# Explanation: I find the painting visually striking due to its bold use of color and abstract shapes. The contrasting colors of yellow, blue, and white create a strong visual impact, while the simple yet interesting forms draw me in. The composition feels balanced, and the overall effect is somewhat mysterious and intriguing. I appreciate the painterly quality and expressive brushstrokes, which give the artwork a sense of depth and texture. It is aesthetically pleasing, therefore, I give it a score of 75.
# 14:37:36 [INFO] → Liking Success: thursday-jeudi.jpg → rating=75.0
# 14:37:36 [INFO] [9/10] Liking: Processing transparent-in-perspective-grooved-1921(1).jpg
# 14:37:36 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:38 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:38 [INFO] AFC remote call 1 is done.
# Liking: 78
# Explanation: The painting has a unique charm due to its abstract and fragmented composition. The use of transparent and overlapping geometric shapes creates a sense of depth and visual interest. The color palette, with its blend of warm oranges and browns contrasted with cool blues and yellows, is pleasing and well-balanced. The hand-drawn lines and the overall slightly imperfect execution lend a sense of character and personality to the work. However, the somewhat chaotic nature of the composition prevents me from rating it higher, as the lack of a clear focal point can be slightly disorienting.
# 14:37:38 [INFO] → Liking Success: transparent-in-perspective-grooved-1921(1).jpg → rating=78.0
# 14:37:38 [INFO] [10/10] Liking: Processing untitled-1885.jpg
# 14:37:38 [INFO] AFC is enabled with max remote calls: 10.
# 14:37:40 [INFO] HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent "HTTP/1.1 200 OK"
# 14:37:40 [INFO] AFC remote call 1 is done.
# Liking: 78
# Explanation: The painting evokes a sense of nostalgia and tranquility. I enjoy the Impressionistic style, with its loose brushstrokes and emphasis on capturing the atmospheric conditions. The depiction of the harbor, with its ships and buildings, is visually appealing. The muted color palette creates a peaceful and serene mood. While the composition may not be groundbreaking, it is nonetheless pleasing to the eye. The overall effect is one of quiet beauty, which resonates with me on a personal level. I like the balance between the sky and the water, and the way the clouds are rendered adds depth to the scene. The boats are realistically portrayed and give the painting a sense of life.
#
# 14:37:40 [INFO] → Liking Success: untitled-1885.jpg → rating=78.0
# 14:37:40 [INFO] ✅ Liking results successfully produced

# %%
#merge all emotion rating dfs into one and save to csv
combined_output_df = [joy_output, sadness_output, fear_output, anger_output, disgust_output, surprise_output, liking_output]
emotion_output = reduce(
    lambda left, right: pd.merge(left,right, on="image", how="outer"),
    combined_output_df
)

emotion_output.to_csv("../output/emotion_output.csv", index=False)

# %% [markdown]
# ### Use enhanced prompt

# %%
joy_output_enhanced = get_response_by_emotion('Joy', prompt_dict = prompt_dict_enhanced)
# Out:
# 16:06:24 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 16:06:49 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 16:06:58 [WARNING] Error on try 2: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 16:07:13 [WARNING] Error on try 3: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 16:07:47 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
sadness_output_enhanced = get_response_by_emotion('Sadness', prompt_dict = prompt_dict_enhanced)
# Out:
# 16:09:53 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 16:10:02 [WARNING] Error on try 2: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
fear_output_enhanced = get_response_by_emotion('Fear', prompt_dict = prompt_dict_enhanced)
# Out:
# 16:11:58 [WARNING] Error on try 1: 'NoneType' object is not subscriptable
# 16:13:11 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 16:13:36 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 16:13:43 [WARNING] Error on try 2: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
anger_output_enhanced = get_response_by_emotion('Anger', prompt_dict = prompt_dict_enhanced)

# %%
disgust_output_enhanced = get_response_by_emotion('Disgust', prompt_dict = prompt_dict_enhanced)

# %%
surprise_output_enhanced = get_response_by_emotion('Surprise', prompt_dict = prompt_dict_enhanced)
# Out:
# 16:17:04 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
liking_output_enhanced = get_response_by_emotion('Liking', prompt_dict = prompt_dict_enhanced)
# Out:
# 16:18:59 [WARNING] Error on try 1: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 16:19:11 [WARNING] Error on try 2: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
#merge all emotion rating dfs into one and save to csv
combined_output_df_enhanced = [joy_output_enhanced, sadness_output_enhanced, fear_output_enhanced, anger_output_enhanced, disgust_output_enhanced, surprise_output_enhanced, liking_output_enhanced]
emotion_output_enhanced = reduce(
    lambda left, right: pd.merge(left,right, on="image", how="outer"),
    combined_output_df_enhanced
)

emotion_output_enhanced.to_csv("../output/emotion_output_enhanced.csv", index=False)

# %% [markdown]
# ------END-------
